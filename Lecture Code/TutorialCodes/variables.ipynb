# %%
myName = "Linn"
myAge = 22
print(myName)
print(myAge)
print(f"My name is {myName} and I am {myAge} years old.")

# line continuation
# print(f"My name i {myName} and " \
#       f"I am {myAge} years old.")
# Out:
# Linn
# 22
# My name is Linn and I am 22 years old.
# My name i Linn and I am 22 years old.
