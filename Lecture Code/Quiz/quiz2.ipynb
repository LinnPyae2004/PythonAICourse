# %%
print(0.1 + 0.2 == 0.3)

# %%
print(f"{0.1:.20f}")
print(f"{0.2:.20f}")
# print(f"{0.1:.20f}")

print(f"{0.1 + 0.2:.1f}")

# %%
a = 0.1
b = 0.2

c = f"{a + b:.1f}"

print(c == "0.3")

# %%
from hidden_functions import *

a = 0.1
b = 0.2

a_bin = dec_to_bin(a)
b_bin = dec_to_bin(b)

adder = FullAdder()

c_bin = adder.add(a_bin, b_bin)
print(a_bin)
print(b_bin)
print(c_bin)

c = bin_to_dec(c_bin)

print(c)
round(c, 1)
# Out:
# 00000000000110011001100110011001
# 00000000001100110011001100110011
# 00000000010011001100110011001100
# 0.2999999523162842
# 0.3
