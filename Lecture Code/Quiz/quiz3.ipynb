# %%
# problem 1
x = 10
y = 5
z = 0

if y > z and x == y:
    print("Statement 1 is true")
elif x > y and x > z:
    print("Statement 2 is true")
else: 
    print("None of the statement was true.")

# %%
# problem 2
x = 10
y = 5
z = 0

if y > z or x == y:
    print("Statement 1 is true")
elif x > y or x > z:
    print("Statement 2 is true")
else:
    print("None of the statement was true")

# %%
# problem 3
x = 10
y = 5
z = 0

if y > z and x == y:
    print("Statement 1 is true")
elif x < y or x > z:
    print("Statement 2 is true")
else:
    print("None of the statement was true")
