# %%
myName = "Linn" # str
myAge = 22 # int
randomNumber = 67.67 # float
mylist = ["apple", "banana", "cherry"] # list
mySet = {"apple", "banana", "cherry", "banana", "cherry"} # set
myExistence = True # bool

myDict = {
    "apple": 2,
    "banana": 10,
    "cherry": 7
} # dict

myBinaryData = b"Hello" # bytes
myGirlfriend = None # none type

# %%
for byte in myBinaryData:
    print(byte)
# Out:
# 72
# 101
# 108
# 108
# 111

# %%
print(myBinaryData)
# Out:
# b'Hello'
